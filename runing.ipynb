# %%
from shengxiao import SHENGXIAO
from paddle.io import DataLoader
import matplotlib.pyplot as plt

# %%
ds = SHENGXIAO(mode='test', transform=True)
# Out:
# Transform is done.

# %%
batched_ds = DataLoader(ds, batch_size=128, shuffle=True)

img, label = next(iter(batched_ds))
plt.imshow(img[0]), label[0]
# Out:
# [2025-11-01 17:52:42,877] [ WARNING] image.py:661 - Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8552711..1.7155793].
# (<matplotlib.image.AxesImage at 0x198d99c4f50>, 'tiger')
